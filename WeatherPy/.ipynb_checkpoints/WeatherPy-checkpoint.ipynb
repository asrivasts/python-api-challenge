# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-----------------------------")

city = "London"
url = "http://api.openweathermap.org/data/2.5/weather?"
record = 0
setnum = 1
output_df = []



for city in cities:
    record = record + 1
    print(f"Processing Record {record} of Set {setnum} | {city}")
    query_url = url + "appid=" + api_key + "&q=" + city
    try:
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        cur_city = weather_json["name"]
        clouds = weather_json["clouds"]["all"]
        tempmax =weather_json["main"]["temp_max"]
        humid = weather_json["main"]["humidity"]
        date = weather_json["dt"]
        lat = weather_json["coord"]["lat"]
        lon = weather_json["coord"]["lon"]
        wind = weather_json["wind"]["speed"]
        country = weather_json["sys"]["country"]
        output_df.append({
            "City" : cur_city,
            "Cloudiness" : clouds,
            "Country" : country,
            "Date" : date,
            "Humidity" : humid,
            "Lat" : lat,
            "Lng" : lon,
            "Max Temp" : tempmax,
            "Wind Speed" : wind
        })
    except:
        print("City not found. Skipping...")
    if (record == 50):
        record = 0
        setnum = setnum+1

print("-----------------------------\n   Data Retrieval Complete   \n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san cristobal
# Processing Record 2 of Set 1 | sangar
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | yurino
# Processing Record 7 of Set 1 | baykalovo
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | zmiyiv
# City not found. Skipping...
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | eskisehir
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | hailar
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | wanning
# Processing Record 19 of Set 1 | krasnovishersk
# Processing Record 20 of Set 1 | quevedo
# Processing Record 21 of Set 1 | paamiut
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | ullapool
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | mabaruma
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | batagay
# Processing Record 35 of Set 1 | bowen
# Processing Record 36 of Set 1 | naze
# Processing Record 37 of Set 1 | norman wells
# Processing Record 38 of Set 1 | grand island
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | constitucion
# Processing Record 43 of Set 1 | ucluelet
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | manokwari
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | ozernovskiy
# Processing Record 48 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 1 | muroto
# Processing Record 50 of Set 1 | takob
# City not found. Skipping...
# Processing Record 1 of Set 2 | yerofey pavlovich
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | bin qirdan
# Processing Record 4 of Set 2 | pizarro
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | tierranueva
# Processing Record 9 of Set 2 | tautira
# Processing Record 10 of Set 2 | stromness
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | labuhan
# Processing Record 15 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | loandjili
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | chodziez
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | praia
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | genhe
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | puerto escondido
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | sept-iles
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | nuevo progreso
# Processing Record 36 of Set 2 | port augusta
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | moa
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | gilbues
# Processing Record 41 of Set 2 | padang
# Processing Record 42 of Set 2 | lengshuitan
# Processing Record 43 of Set 2 | high level
# Processing Record 44 of Set 2 | half moon bay
# Processing Record 45 of Set 2 | mitsamiouli
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | deputatskiy
# Processing Record 48 of Set 2 | cap malheureux
# Processing Record 49 of Set 2 | puerto madryn
# Processing Record 50 of Set 2 | denpasar
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | kavaratti
# Processing Record 3 of Set 3 | nuuk
# Processing Record 4 of Set 3 | goundam
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | omaruru
# Processing Record 7 of Set 3 | ahuimanu
# Processing Record 8 of Set 3 | lang suan
# Processing Record 9 of Set 3 | riyadh
# Processing Record 10 of Set 3 | uddevalla
# Processing Record 11 of Set 3 | san angelo
# Processing Record 12 of Set 3 | bunda
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | igrim
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | perambalur
# Processing Record 18 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | santa maria
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | port lincoln
# Processing Record 23 of Set 3 | puerto narino
# Processing Record 24 of Set 3 | novoagansk
# Processing Record 25 of Set 3 | eyl
# Processing Record 26 of Set 3 | mildura
# Processing Record 27 of Set 3 | bhimunipatnam
# Processing Record 28 of Set 3 | zhangye
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | tuktoyaktuk
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | sao joao da barra
# Processing Record 34 of Set 3 | belmonte
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | villa carlos paz
# Processing Record 37 of Set 3 | leesburg
# Processing Record 38 of Set 3 | arlit
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | teya
# Processing Record 41 of Set 3 | quatre cocos
# Processing Record 42 of Set 3 | jalu
# Processing Record 43 of Set 3 | samarai
# Processing Record 44 of Set 3 | huinan
# Processing Record 45 of Set 3 | intipuca
# Processing Record 46 of Set 3 | lask
# Processing Record 47 of Set 3 | kucove
# Processing Record 48 of Set 3 | conceicao do araguaia
# Processing Record 49 of Set 3 | klaksvik
# Processing Record 50 of Set 3 | kalemie
# Processing Record 1 of Set 4 | saint-augustin
# Processing Record 2 of Set 4 | ayagoz
# Processing Record 3 of Set 4 | kapaa
# Processing Record 4 of Set 4 | hami
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | namatanai
# Processing Record 8 of Set 4 | big bend
# Processing Record 9 of Set 4 | bulawayo
# Processing Record 10 of Set 4 | guia de isora
# Processing Record 11 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | salamiyah
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | shostka
# Processing Record 16 of Set 4 | mataram
# Processing Record 17 of Set 4 | seymchan
# Processing Record 18 of Set 4 | vaini
# Processing Record 19 of Set 4 | pevek
# Processing Record 20 of Set 4 | waipawa
# Processing Record 21 of Set 4 | chapais
# Processing Record 22 of Set 4 | xiantao
# Processing Record 23 of Set 4 | kamina
# Processing Record 24 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 4 | san quintin
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | geraldton
# Processing Record 28 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 4 | concepcion del oro
# Processing Record 30 of Set 4 | port macquarie
# Processing Record 31 of Set 4 | am timan
# Processing Record 32 of Set 4 | barra do corda
# Processing Record 33 of Set 4 | coos bay
# Processing Record 34 of Set 4 | havoysund
# Processing Record 35 of Set 4 | circleville
# Processing Record 36 of Set 4 | rundu
# Processing Record 37 of Set 4 | mar del plata
# Processing Record 38 of Set 4 | banda aceh
# Processing Record 39 of Set 4 | san javier
# Processing Record 40 of Set 4 | boyolangu
# Processing Record 41 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 4 | beyneu
# Processing Record 44 of Set 4 | neiafu
# Processing Record 45 of Set 4 | lasa
# Processing Record 46 of Set 4 | aberdeen
# Processing Record 47 of Set 4 | walvis bay
# Processing Record 48 of Set 4 | codrington
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | ilhabela
# Processing Record 1 of Set 5 | bac lieu
# City not found. Skipping...
# Processing Record 2 of Set 5 | forrest city
# Processing Record 3 of Set 5 | kirovskiy
# Processing Record 4 of Set 5 | morro bay
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | uenohara
# Processing Record 7 of Set 5 | nelson bay
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | taoudenni
# Processing Record 10 of Set 5 | berdigestyakh
# Processing Record 11 of Set 5 | kalabo
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | neftcala
# Processing Record 14 of Set 5 | sciacca
# Processing Record 15 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 5 | novikovo
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | arona
# Processing Record 19 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 5 | poum
# Processing Record 21 of Set 5 | tombouctou
# Processing Record 22 of Set 5 | antalaha
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | kailua
# Processing Record 25 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 5 | harper
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 5 | houma
# Processing Record 30 of Set 5 | sosnovo
# Processing Record 31 of Set 5 | solnechnogorsk
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | faanui
# Processing Record 35 of Set 5 | perth
# Processing Record 36 of Set 5 | plainview
# Processing Record 37 of Set 5 | fonte boa
# Processing Record 38 of Set 5 | portland
# Processing Record 39 of Set 5 | forio
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | kampot
# Processing Record 44 of Set 5 | kahului
# Processing Record 45 of Set 5 | alyangula
# Processing Record 46 of Set 5 | ust-kulom
# Processing Record 47 of Set 5 | yar-sale
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | port elizabeth
# Processing Record 50 of Set 5 | tadine
# Processing Record 1 of Set 6 | namtsy
# Processing Record 2 of Set 6 | nadvoitsy
# Processing Record 3 of Set 6 | zagan
# Processing Record 4 of Set 6 | avarua
# Processing Record 5 of Set 6 | kendari
# Processing Record 6 of Set 6 | shingu
# Processing Record 7 of Set 6 | ponoka
# Processing Record 8 of Set 6 | umred
# Processing Record 9 of Set 6 | cotonou
# Processing Record 10 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 6 | christchurch
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | pimentel
# Processing Record 14 of Set 6 | saint-georges
# Processing Record 15 of Set 6 | camabatela
# Processing Record 16 of Set 6 | sabang
# Processing Record 17 of Set 6 | camacha
# Processing Record 18 of Set 6 | hualmay
# Processing Record 19 of Set 6 | turinskaya sloboda
# Processing Record 20 of Set 6 | kaitangata
# Processing Record 21 of Set 6 | tema
# Processing Record 22 of Set 6 | kamaishi
# Processing Record 23 of Set 6 | hashtrud
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | vila praia de ancora
# Processing Record 26 of Set 6 | malanje
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | ovalle
# Processing Record 29 of Set 6 | verkhnyaya inta
# Processing Record 30 of Set 6 | yarmouth
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | cloquet
# Processing Record 33 of Set 6 | gelendzhik
# Processing Record 34 of Set 6 | dourados
# Processing Record 35 of Set 6 | sitka
# Processing Record 36 of Set 6 | aktash
# City not found. Skipping...
# Processing Record 37 of Set 6 | whitehorse
# Processing Record 38 of Set 6 | la baule-escoublac
# Processing Record 39 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 6 | vostok
# Processing Record 41 of Set 6 | saint-donat-de-montcalm
# Processing Record 42 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 6 | clyde river
# Processing Record 44 of Set 6 | khorixas
# Processing Record 45 of Set 6 | banswara
# Processing Record 46 of Set 6 | phalaborwa
# Processing Record 47 of Set 6 | araouane
# Processing Record 48 of Set 6 | misratah
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | miyakonojo
# Processing Record 1 of Set 7 | lata
# Processing Record 2 of Set 7 | buraydah
# Processing Record 3 of Set 7 | margate
# Processing Record 4 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 7 | lamu
# Processing Record 6 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 7 | shorewood
# Processing Record 8 of Set 7 | rawson
# Processing Record 9 of Set 7 | alexandria
# Processing Record 10 of Set 7 | ekibastuz
# Processing Record 11 of Set 7 | saint-pierre
# Processing Record 12 of Set 7 | yuli
# Processing Record 13 of Set 7 | kupino
# Processing Record 14 of Set 7 | nantucket
# Processing Record 15 of Set 7 | hohhot
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | potrero del llano
# Processing Record 18 of Set 7 | aktau
# Processing Record 19 of Set 7 | kjollefjord
# Processing Record 20 of Set 7 | bocas del toro
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | huilong
# Processing Record 24 of Set 7 | kayerkan
# Processing Record 25 of Set 7 | egvekinot
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | kaspiysk
# Processing Record 28 of Set 7 | turbat
# Processing Record 29 of Set 7 | yumen
# Processing Record 30 of Set 7 | tiarei
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | san carlos
# Processing Record 33 of Set 7 | daru
# Processing Record 34 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 7 | rio gallegos
# Processing Record 36 of Set 7 | upernavik
# Processing Record 37 of Set 7 | cockburn town
# Processing Record 38 of Set 7 | faya
# Processing Record 39 of Set 7 | bereda
# Processing Record 40 of Set 7 | wajima
# Processing Record 41 of Set 7 | ramgarh
# Processing Record 42 of Set 7 | sawtell
# Processing Record 43 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 7 | broken hill
# Processing Record 45 of Set 7 | westport
# Processing Record 46 of Set 7 | victoria
# Processing Record 47 of Set 7 | nishihara
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | thoen
# Processing Record 50 of Set 7 | kurilsk
# Processing Record 1 of Set 8 | matongo
# Processing Record 2 of Set 8 | hirara
# Processing Record 3 of Set 8 | udachnyy
# Processing Record 4 of Set 8 | bilibino
# Processing Record 5 of Set 8 | kosgi
# City not found. Skipping...
# Processing Record 6 of Set 8 | mount gambier
# Processing Record 7 of Set 8 | port blair
# Processing Record 8 of Set 8 | rio de janeiro
# Processing Record 9 of Set 8 | morgan city
# Processing Record 10 of Set 8 | strelka
# Processing Record 11 of Set 8 | la romana
# Processing Record 12 of Set 8 | barabinsk
# Processing Record 13 of Set 8 | fort nelson
# Processing Record 14 of Set 8 | norrtalje
# Processing Record 15 of Set 8 | luderitz
# Processing Record 16 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 8 | qasigiannguit
# Processing Record 18 of Set 8 | visby
# Processing Record 19 of Set 8 | havre-saint-pierre
# Processing Record 20 of Set 8 | port hedland
# Processing Record 21 of Set 8 | touros
# Processing Record 22 of Set 8 | harbour breton
# Processing Record 23 of Set 8 | okhotsk
# Processing Record 24 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 8 | artyom
# Processing Record 26 of Set 8 | shestakovo
# Processing Record 27 of Set 8 | sidi ali
# Processing Record 28 of Set 8 | bilma
# Processing Record 29 of Set 8 | iqaluit
# Processing Record 30 of Set 8 | college
# Processing Record 31 of Set 8 | pierre
# Processing Record 32 of Set 8 | mata
# Processing Record 33 of Set 8 | katima mulilo
# Processing Record 34 of Set 8 | luangwa
# Processing Record 35 of Set 8 | ponta do sol
# Processing Record 36 of Set 8 | ewa beach
# Processing Record 37 of Set 8 | palia kalan
# Processing Record 38 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 8 | springbok
# Processing Record 40 of Set 8 | buala
# Processing Record 41 of Set 8 | fare
# Processing Record 42 of Set 8 | powell river
# Processing Record 43 of Set 8 | hobyo
# Processing Record 44 of Set 8 | rio grande
# Processing Record 45 of Set 8 | hasaki
# Processing Record 46 of Set 8 | alta floresta
# Processing Record 47 of Set 8 | longyearbyen
# Processing Record 48 of Set 8 | gbadolite
# Processing Record 49 of Set 8 | guijalo
# Processing Record 50 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 9 | tevriz
# Processing Record 4 of Set 9 | sadao
# Processing Record 5 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 9 | husum
# Processing Record 7 of Set 9 | coahuayana
# Processing Record 8 of Set 9 | baherden
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | severodvinsk
# Processing Record 11 of Set 9 | jasper
# Processing Record 12 of Set 9 | sembe
# City not found. Skipping...
# Processing Record 13 of Set 9 | port hueneme
# Processing Record 14 of Set 9 | korla
# City not found. Skipping...
# Processing Record 15 of Set 9 | mount isa
# Processing Record 16 of Set 9 | vanimo
# Processing Record 17 of Set 9 | ponerihouen
# Processing Record 18 of Set 9 | athabasca
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | jacareacanga
# Processing Record 21 of Set 9 | chimoio
# Processing Record 22 of Set 9 | grand gaube
# Processing Record 23 of Set 9 | samarina
# Processing Record 24 of Set 9 | buchanan
# Processing Record 25 of Set 9 | stornoway
# City not found. Skipping...
# Processing Record 26 of Set 9 | agadir
# Processing Record 27 of Set 9 | taltal
# Processing Record 28 of Set 9 | miraflores
# Processing Record 29 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 9 | berbera
# City not found. Skipping...
# Processing Record 31 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 32 of Set 9 | makakilo city
# Processing Record 33 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 9 | galesong
# Processing Record 35 of Set 9 | beringovskiy
# Processing Record 36 of Set 9 | brigantine
# Processing Record 37 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 9 | stjordalshalsen
# Processing Record 39 of Set 9 | kieta
# Processing Record 40 of Set 9 | likoporia
# City not found. Skipping...
# Processing Record 41 of Set 9 | redlands
# Processing Record 42 of Set 9 | dauriya
# Processing Record 43 of Set 9 | muros
# Processing Record 44 of Set 9 | acajutla
# Processing Record 45 of Set 9 | isangel
# Processing Record 46 of Set 9 | avera
# Processing Record 47 of Set 9 | saint albans
# Processing Record 48 of Set 9 | upington
# Processing Record 49 of Set 9 | gushikawa
# Processing Record 50 of Set 9 | malinovoye ozero
# Processing Record 1 of Set 10 | eenhana
# Processing Record 2 of Set 10 | ereymentau
# Processing Record 3 of Set 10 | solnechnyy
# Processing Record 4 of Set 10 | krasnoselkup
# City not found. Skipping...
# Processing Record 5 of Set 10 | salalah
# Processing Record 6 of Set 10 | dingle
# Processing Record 7 of Set 10 | aktas
# City not found. Skipping...
# Processing Record 8 of Set 10 | karpathos
# Processing Record 9 of Set 10 | guanare
# Processing Record 10 of Set 10 | teshie
# Processing Record 11 of Set 10 | los teques
# Processing Record 12 of Set 10 | talcahuano
# Processing Record 13 of Set 10 | pokrovka
# Processing Record 14 of Set 10 | buta
# Processing Record 15 of Set 10 | keffi
# Processing Record 16 of Set 10 | saint anthony
# Processing Record 17 of Set 10 | gaogou
# Processing Record 18 of Set 10 | hofn
# Processing Record 19 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 10 | mayor pablo lagerenza
# Processing Record 21 of Set 10 | saurimo
# Processing Record 22 of Set 10 | grindavik
# Processing Record 23 of Set 10 | paita
# Processing Record 24 of Set 10 | xunchang
# Processing Record 25 of Set 10 | bandarbeyla
# Processing Record 26 of Set 10 | fukue
# Processing Record 27 of Set 10 | druzhba
# Processing Record 28 of Set 10 | chicama
# Processing Record 29 of Set 10 | mackenzie
# Processing Record 30 of Set 10 | kalmunai
# Processing Record 31 of Set 10 | finnsnes
# Processing Record 32 of Set 10 | kathu
# Processing Record 33 of Set 10 | zavetnoye
# Processing Record 34 of Set 10 | bekhteyevka
# Processing Record 35 of Set 10 | diffa
# Processing Record 36 of Set 10 | orhangazi
# Processing Record 37 of Set 10 | brazzaville
# Processing Record 38 of Set 10 | manubah
# City not found. Skipping...
# Processing Record 39 of Set 10 | cap-aux-meules
# Processing Record 40 of Set 10 | muhos
# Processing Record 41 of Set 10 | vanavara
# Processing Record 42 of Set 10 | marystown
# Processing Record 43 of Set 10 | elat
# Processing Record 44 of Set 10 | broome
# Processing Record 45 of Set 10 | bathsheba
# Processing Record 46 of Set 10 | evensk
# Processing Record 47 of Set 10 | ocean city
# Processing Record 48 of Set 10 | shambu
# Processing Record 49 of Set 10 | bang saphan
# Processing Record 50 of Set 10 | shubarkuduk
# Processing Record 1 of Set 11 | meulaboh
# Processing Record 2 of Set 11 | williston
# Processing Record 3 of Set 11 | seoul
# Processing Record 4 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 5 of Set 11 | svetlogorsk
# Processing Record 6 of Set 11 | srivardhan
# Processing Record 7 of Set 11 | harlingen
# Processing Record 8 of Set 11 | baker city
# Processing Record 9 of Set 11 | funadhoo
# Processing Record 10 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 11 | nome
# Processing Record 12 of Set 11 | veere
# Processing Record 13 of Set 11 | manaure
# Processing Record 14 of Set 11 | san patricio
# Processing Record 15 of Set 11 | tazovskiy
# Processing Record 16 of Set 11 | matara
# Processing Record 17 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 11 | pangody
# Processing Record 19 of Set 11 | tateyama
# Processing Record 20 of Set 11 | kongolo
# Processing Record 21 of Set 11 | acapulco
# Processing Record 22 of Set 11 | bridlington
# Processing Record 23 of Set 11 | ola
# Processing Record 24 of Set 11 | port-gentil
# Processing Record 25 of Set 11 | malard
# Processing Record 26 of Set 11 | ballina
# Processing Record 27 of Set 11 | bogashevo
# Processing Record 28 of Set 11 | inhambane
# Processing Record 29 of Set 11 | victoria point
# Processing Record 30 of Set 11 | toora-khem
# Processing Record 31 of Set 11 | erzincan
# Processing Record 32 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 11 | pacific grove
# Processing Record 34 of Set 11 | laguna
# Processing Record 35 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 36 of Set 11 | charters towers
# Processing Record 37 of Set 11 | toguchin
# Processing Record 38 of Set 11 | mecca
# Processing Record 39 of Set 11 | luchegorsk
# Processing Record 40 of Set 11 | maceio
# Processing Record 41 of Set 11 | atar
# Processing Record 42 of Set 11 | lorengau
# Processing Record 43 of Set 11 | pemberton
# Processing Record 44 of Set 11 | miyako
# Processing Record 45 of Set 11 | isla vista
# Processing Record 46 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 11 | olinda
# Processing Record 48 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 49 of Set 11 | sobolevo
# Processing Record 50 of Set 11 | makat
# Processing Record 1 of Set 12 | labuan
# Processing Record 2 of Set 12 | santa margarita
# Processing Record 3 of Set 12 | yulara
# Processing Record 4 of Set 12 | kenai
# Processing Record 5 of Set 12 | pitimbu
# Processing Record 6 of Set 12 | san jeronimo
# Processing Record 7 of Set 12 | payson
# Processing Record 8 of Set 12 | kesova gora
# Processing Record 9 of Set 12 | touba
# Processing Record 10 of Set 12 | socastee
# Processing Record 11 of Set 12 | changji
# Processing Record 12 of Set 12 | grand-lahou
# Processing Record 13 of Set 12 | mehamn
# Processing Record 14 of Set 12 | borovoy
# Processing Record 15 of Set 12 | okitipupa
# Processing Record 16 of Set 12 | krasnyy kholm
# Processing Record 17 of Set 12 | ilam
# Processing Record 18 of Set 12 | namibe
# Processing Record 19 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 12 | kindia
# Processing Record 22 of Set 12 | kununurra
# Processing Record 23 of Set 12 | lipari
# Processing Record 24 of Set 12 | kiruna
# Processing Record 25 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 12 | datong
# Processing Record 27 of Set 12 | minas
# Processing Record 28 of Set 12 | necochea
# Processing Record 29 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 12 | yerbogachen
# Processing Record 31 of Set 12 | severobaykalsk
# Processing Record 32 of Set 12 | yeppoon
# Processing Record 33 of Set 12 | calatayud
# Processing Record 34 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 12 | raudeberg
# Processing Record 36 of Set 12 | zhuhai
# Processing Record 37 of Set 12 | peniche
# Processing Record 38 of Set 12 | dese
# Processing Record 39 of Set 12 | timra
# Processing Record 40 of Set 12 | narsaq
# Processing Record 41 of Set 12 | sao filipe
# Processing Record 42 of Set 12 | chumikan
# Processing Record 43 of Set 12 | emerald
# Processing Record 44 of Set 12 | yarega
# Processing Record 45 of Set 12 | tutoia
# Processing Record 46 of Set 12 | durusu
# Processing Record 47 of Set 12 | skjervoy

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_out_df = pd.DataFrame(output_df)
weather_out_df.to_csv("output/city_data.csv")

weather_out_df.count()
# Out:
# City          534
# Cloudiness    534
# Country       534
# Date          534
# Humidity      534
# Lat           534
# Lng           534
# Max Temp      534
# Wind Speed    534
# dtype: int64

# %%
weather_out_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  San Cristobal          65      HN  1575580197        53  14.68  -86.92
# 1         Sangar          97      RU  1575580197        97  63.92  127.47
# 2      Hithadhoo         100      MV  1575580197        78  -0.60   73.08
# 3        Rikitea          51      PF  1575580197        82 -23.12 -134.97
# 4         Yurino          90      RU  1575580197        91  56.29   46.29
#
#    Max Temp  Wind Speed
# 0    298.97        2.31
# 1    231.77        2.71
# 2    301.24        2.49
# 3    298.65        4.68
# 4    274.15        9.00

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
ax = weather_out_df.plot(kind='scatter', x='Lat', y='Max Temp', edgecolors="black", c="lightblue")

graph_date = weather_out_df["Date"].max()
dt = datetime.fromtimestamp(graph_date)
graph_datef = dt.strftime("%m/%d/%Y")
graph_datef

ax.grid()
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (°F)")
ax.set_title(f"City Latitude vs. Max Temperature ({graph_datef})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature (12/05/2019)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax = weather_out_df.plot(kind='scatter', x='Lat', y='Humidity', edgecolors="black", c="lightblue")

ax.grid()
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title(f"City Latitude vs. Humidity ({graph_datef})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity (12/05/2019)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax = weather_out_df.plot(kind='scatter', x='Lat', y='Cloudiness', edgecolors="black", c="lightblue")

ax.grid()
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title(f"City Latitude vs. Cloudiness ({graph_datef})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness (12/05/2019)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Out:
# '12/05/2019'

# %%
weather_json
# Out:
# {'coord': {'lon': 20.97, 'lat': 70.03},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 276.15,
#   'pressure': 970,
#   'humidity': 59,
#   'temp_min': 276.15,
#   'temp_max': 276.15},
#  'visibility': 10000,
#  'wind': {'speed': 4.6, 'deg': 100},
#  'clouds': {'all': 34},
#  'dt': 1575580234,
#  'sys': {'type': 1, 'id': 1634, 'country': 'NO', 'sunrise': 0, 'sunset': 0},
#  'timezone': 3600,
#  'id': 777682,
#  'name': 'Skjervoy',
#  'cod': 200}
